# %% [markdown]
# ### Occupancy Detection Data Set
# Описание данных: https://archive.ics.uci.edu/ml/datasets/Occupancy+Detection+
#
# Переменные:
# * Дата год-месяц-день час:минута:секунда
# * Температура, в градусах Цельсия
# * Относительная влажность, %
# * Свет, в лк
# * CO2, в ppm
# * Влажность, в kgwater-vapor/kg-air
# * Занятость комнаты, 0 или 1, 0 - не занята, 1 - занята

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
#Считываем данные
data = pd.read_csv('dataset.csv', sep = ',', engine = 'python')

# %%
#Выведем то, что прочитали
data
# Out:
#                      date  Temperature   Humidity       Light          CO2  \
# 0     2015-02-02 14:19:00    23.700000  26.272000  585.200000   749.200000
# 1     2015-02-02 14:19:59    23.718000  26.290000  578.400000   760.400000
# 2     2015-02-02 14:21:00    23.730000  26.230000  572.666667   769.666667
# 3     2015-02-02 14:22:00    23.722500  26.125000  493.750000   774.750000
# 4     2015-02-02 14:23:00    23.754000  26.200000  488.600000   779.000000
# 5     2015-02-02 14:23:59    23.760000  26.260000  568.666667   790.000000
# 6     2015-02-02 14:25:00    23.730000  26.290000  536.333333   798.000000
# 7     2015-02-02 14:25:59    23.754000  26.290000  509.000000   797.000000
# 8     2015-02-02 14:26:59    23.754000  26.350000  476.000000   803.200000
# 9     2015-02-02 14:28:00    23.736000  26.390000  510.000000   809.000000
# 10    2015-02-02 14:29:00    23.745000  26.445000  481.500000   815.250000
# 11    2015-02-02 14:30:00    23.700000  26.560000  481.800000   824.000000
# 12    2015-02-02 14:31:00    23.700000  26.600000  475.250000   832.000000
# 13    2015-02-02 14:31:59    23.700000  26.700000  469.000000   845.333333
# 14    2015-02-02 14:32:59    23.700000  26.774000  464.000000   852.400000
# 15    2015-02-02 14:34:00    23.700000  26.890000  464.000000   861.000000
# 16    2015-02-02 14:35:00    23.700000  26.972500  455.000000   880.000000
# 17    2015-02-02 14:36:00    23.600000  26.890000  454.000000   891.000000
# 18    2015-02-02 14:37:00    23.640000  26.976000  458.000000   897.600000
# 19    2015-02-02 14:38:00    23.650000  27.050000  464.000000   900.500000
# 20    2015-02-02 14:38:59    23.640000  27.100000  473.000000   908.800000
# 21    2015-02-02 14:39:59    23.600000  27.160000  464.000000   918.000000
# 22    2015-02-02 14:41:00    23.600000  27.236000  498.400000   925.200000
# 23    2015-02-02 14:42:00    23.600000  27.290000  530.200000   929.400000
# 24    2015-02-02 14:43:00    23.600000  27.330000  533.600000   936.400000
# 25    2015-02-02 14:44:00    23.600000  27.340000  524.250000   950.000000
# 26    2015-02-02 14:44:59    23.625000  27.392500  498.666667   961.000000
# 27    2015-02-02 14:45:59    23.600000  27.390000  516.333333   963.000000
# 28    2015-02-02 14:47:00    23.600000  27.412000  501.200000   958.600000
# 29    2015-02-02 14:48:00    23.600000  27.500000  522.000000   965.333333
# ...                   ...          ...        ...         ...          ...
# 2635  2015-02-04 10:14:00    23.790000  26.310000  763.000000  1158.200000
# 2636  2015-02-04 10:14:59    23.790000  26.315000  758.250000  1160.250000
# 2637  2015-02-04 10:15:59    23.890000  26.390000  755.500000  1166.000000
# 2638  2015-02-04 10:17:00    23.890000  26.365000  758.250000  1164.750000
# 2639  2015-02-04 10:18:00    23.890000  26.290000  772.750000  1163.250000
# 2640  2015-02-04 10:19:00    23.984286  26.375714  767.000000  1172.714286
# 2641  2015-02-04 10:20:00    24.000000  26.365000  774.500000  1182.000000
# 2642  2015-02-04 10:21:00    24.050000  26.340000  774.500000  1182.000000
# 2643  2015-02-04 10:21:59    24.080000  26.370000  769.800000  1187.600000
# 2644  2015-02-04 10:23:00    24.100000  26.566667  758.333333  1191.333333
# 2645  2015-02-04 10:24:00    24.100000  26.472500  775.750000  1213.750000
# 2646  2015-02-04 10:25:00    24.100000  26.154000  775.000000  1194.000000
# 2647  2015-02-04 10:25:59    24.100000  25.958000  783.400000  1173.400000
# 2648  2015-02-04 10:27:00    24.100000  25.918000  789.600000  1160.200000
# 2649  2015-02-04 10:27:59    24.100000  25.892500  797.500000  1156.250000
# 2650  2015-02-04 10:28:59    24.100000  25.832000  799.000000  1139.000000
# 2651  2015-02-04 10:30:00    24.175000  25.840000  782.500000  1140.500000
# 2652  2015-02-04 10:31:00    24.200000  25.891667  786.166667  1145.333333
# 2653  2015-02-04 10:32:00    24.200000  25.890000  794.250000  1149.250000
# 2654  2015-02-04 10:33:00    24.200000  25.890000  797.500000  1152.500000
# 2655  2015-02-04 10:34:00    24.200000  25.890000  787.000000  1153.250000
# 2656  2015-02-04 10:34:59    24.218000  25.912000  805.000000  1152.400000
# 2657  2015-02-04 10:36:00    24.260000  25.891667  798.000000  1146.166667
# 2658  2015-02-04 10:37:00    24.290000  25.978000  793.000000  1145.400000
# 2659  2015-02-04 10:38:00    24.290000  25.852000  801.400000  1140.800000
# 2660  2015-02-04 10:38:59    24.290000  25.700000  808.000000  1150.250000
# 2661  2015-02-04 10:40:00    24.330000  25.736000  809.800000  1129.200000
# 2662  2015-02-04 10:40:59    24.330000  25.700000  817.000000  1125.800000
# 2663  2015-02-04 10:41:59    24.356667  25.700000  813.000000  1123.000000
# 2664  2015-02-04 10:43:00    24.408333  25.681667  798.000000  1124.000000
#
#       HumidityRatio  Occupancy
# 0          0.004764          1
# 1          0.004773          1
# 2          0.004765          1
# 3          0.004744          1
# 4          0.004767          1
# 5          0.004779          1
# 6          0.004776          1
# 7          0.004783          1
# 8          0.004794          1
# 9          0.004796          1
# 10         0.004809          1
# 11         0.004817          1
# 12         0.004824          1
# 13         0.004842          1
# 14         0.004856          1
# 15         0.004877          1
# 16         0.004892          1
# 17         0.004848          1
# 18         0.004875          1
# 19         0.004891          1
# 20         0.004898          1
# 21         0.004897          1
# 22         0.004910          1
# 23         0.004920          1
# 24         0.004928          1
# 25         0.004929          1
# 26         0.004946          1
# 27         0.004938          1
# 28         0.004942          1
# 29         0.004958          1
# ...             ...        ...
# 2635       0.004797          1
# 2636       0.004798          1
# 2637       0.004841          1
# 2638       0.004837          1
# 2639       0.004823          1
# 2640       0.004866          1
# 2641       0.004869          1
# 2642       0.004879          1
# 2643       0.004893          1
# 2644       0.004936          1
# 2645       0.004919          1
# 2646       0.004859          1
# 2647       0.004822          1
# 2648       0.004815          1
# 2649       0.004810          1
# 2650       0.004799          1
# 2651       0.004822          1
# 2652       0.004839          1
# 2653       0.004839          1
# 2654       0.004839          1
# 2655       0.004839          1
# 2656       0.004848          1
# 2657       0.004857          1
# 2658       0.004882          1
# 2659       0.004858          1
# 2660       0.004829          1
# 2661       0.004848          1
# 2662       0.004841          1
# 2663       0.004849          1
# 2664       0.004860          1
#
# [2665 rows x 7 columns]

# %%
#Вывод средствами питона
print(data)
# Out:
#                      date  Temperature   Humidity       Light          CO2  \
# 0     2015-02-02 14:19:00    23.700000  26.272000  585.200000   749.200000
# 1     2015-02-02 14:19:59    23.718000  26.290000  578.400000   760.400000
# 2     2015-02-02 14:21:00    23.730000  26.230000  572.666667   769.666667
# 3     2015-02-02 14:22:00    23.722500  26.125000  493.750000   774.750000
# 4     2015-02-02 14:23:00    23.754000  26.200000  488.600000   779.000000
# 5     2015-02-02 14:23:59    23.760000  26.260000  568.666667   790.000000
# 6     2015-02-02 14:25:00    23.730000  26.290000  536.333333   798.000000
# 7     2015-02-02 14:25:59    23.754000  26.290000  509.000000   797.000000
# 8     2015-02-02 14:26:59    23.754000  26.350000  476.000000   803.200000
# 9     2015-02-02 14:28:00    23.736000  26.390000  510.000000   809.000000
# 10    2015-02-02 14:29:00    23.745000  26.445000  481.500000   815.250000
# 11    2015-02-02 14:30:00    23.700000  26.560000  481.800000   824.000000
# 12    2015-02-02 14:31:00    23.700000  26.600000  475.250000   832.000000
# 13    2015-02-02 14:31:59    23.700000  26.700000  469.000000   845.333333
# 14    2015-02-02 14:32:59    23.700000  26.774000  464.000000   852.400000
# 15    2015-02-02 14:34:00    23.700000  26.890000  464.000000   861.000000
# 16    2015-02-02 14:35:00    23.700000  26.972500  455.000000   880.000000
# 17    2015-02-02 14:36:00    23.600000  26.890000  454.000000   891.000000
# 18    2015-02-02 14:37:00    23.640000  26.976000  458.000000   897.600000
# 19    2015-02-02 14:38:00    23.650000  27.050000  464.000000   900.500000
# 20    2015-02-02 14:38:59    23.640000  27.100000  473.000000   908.800000
# 21    2015-02-02 14:39:59    23.600000  27.160000  464.000000   918.000000
# 22    2015-02-02 14:41:00    23.600000  27.236000  498.400000   925.200000
# 23    2015-02-02 14:42:00    23.600000  27.290000  530.200000   929.400000
# 24    2015-02-02 14:43:00    23.600000  27.330000  533.600000   936.400000
# 25    2015-02-02 14:44:00    23.600000  27.340000  524.250000   950.000000
# 26    2015-02-02 14:44:59    23.625000  27.392500  498.666667   961.000000
# 27    2015-02-02 14:45:59    23.600000  27.390000  516.333333   963.000000
# 28    2015-02-02 14:47:00    23.600000  27.412000  501.200000   958.600000
# 29    2015-02-02 14:48:00    23.600000  27.500000  522.000000   965.333333
# ...                   ...          ...        ...         ...          ...
# 2635  2015-02-04 10:14:00    23.790000  26.310000  763.000000  1158.200000
# 2636  2015-02-04 10:14:59    23.790000  26.315000  758.250000  1160.250000
# 2637  2015-02-04 10:15:59    23.890000  26.390000  755.500000  1166.000000
# 2638  2015-02-04 10:17:00    23.890000  26.365000  758.250000  1164.750000
# 2639  2015-02-04 10:18:00    23.890000  26.290000  772.750000  1163.250000
# 2640  2015-02-04 10:19:00    23.984286  26.375714  767.000000  1172.714286
# 2641  2015-02-04 10:20:00    24.000000  26.365000  774.500000  1182.000000
# 2642  2015-02-04 10:21:00    24.050000  26.340000  774.500000  1182.000000
# 2643  2015-02-04 10:21:59    24.080000  26.370000  769.800000  1187.600000
# 2644  2015-02-04 10:23:00    24.100000  26.566667  758.333333  1191.333333
# 2645  2015-02-04 10:24:00    24.100000  26.472500  775.750000  1213.750000
# 2646  2015-02-04 10:25:00    24.100000  26.154000  775.000000  1194.000000
# 2647  2015-02-04 10:25:59    24.100000  25.958000  783.400000  1173.400000
# 2648  2015-02-04 10:27:00    24.100000  25.918000  789.600000  1160.200000
# 2649  2015-02-04 10:27:59    24.100000  25.892500  797.500000  1156.250000
# 2650  2015-02-04 10:28:59    24.100000  25.832000  799.000000  1139.000000
# 2651  2015-02-04 10:30:00    24.175000  25.840000  782.500000  1140.500000
# 2652  2015-02-04 10:31:00    24.200000  25.891667  786.166667  1145.333333
# 2653  2015-02-04 10:32:00    24.200000  25.890000  794.250000  1149.250000
# 2654  2015-02-04 10:33:00    24.200000  25.890000  797.500000  1152.500000
# 2655  2015-02-04 10:34:00    24.200000  25.890000  787.000000  1153.250000
# 2656  2015-02-04 10:34:59    24.218000  25.912000  805.000000  1152.400000
# 2657  2015-02-04 10:36:00    24.260000  25.891667  798.000000  1146.166667
# 2658  2015-02-04 10:37:00    24.290000  25.978000  793.000000  1145.400000
# 2659  2015-02-04 10:38:00    24.290000  25.852000  801.400000  1140.800000
# 2660  2015-02-04 10:38:59    24.290000  25.700000  808.000000  1150.250000
# 2661  2015-02-04 10:40:00    24.330000  25.736000  809.800000  1129.200000
# 2662  2015-02-04 10:40:59    24.330000  25.700000  817.000000  1125.800000
# 2663  2015-02-04 10:41:59    24.356667  25.700000  813.000000  1123.000000
# 2664  2015-02-04 10:43:00    24.408333  25.681667  798.000000  1124.000000
#
#       HumidityRatio  Occupancy
# 0          0.004764          1
# 1          0.004773          1
# 2          0.004765          1
# 3          0.004744          1
# 4          0.004767          1
# 5          0.004779          1
# 6          0.004776          1
# 7          0.004783          1
# 8          0.004794          1
# 9          0.004796          1
# 10         0.004809          1
# 11         0.004817          1
# 12         0.004824          1
# 13         0.004842          1
# 14         0.004856          1
# 15         0.004877          1
# 16         0.004892          1
# 17         0.004848          1
# 18         0.004875          1
# 19         0.004891          1
# 20         0.004898          1
# 21         0.004897          1
# 22         0.004910          1
# 23         0.004920          1
# 24         0.004928          1
# 25         0.004929          1
# 26         0.004946          1
# 27         0.004938          1
# 28         0.004942          1
# 29         0.004958          1
# ...             ...        ...
# 2635       0.004797          1
# 2636       0.004798          1
# 2637       0.004841          1
# 2638       0.004837          1
# 2639       0.004823          1
# 2640       0.004866          1
# 2641       0.004869          1
# 2642       0.004879          1
# 2643       0.004893          1
# 2644       0.004936          1
# 2645       0.004919          1
# 2646       0.004859          1
# 2647       0.004822          1
# 2648       0.004815          1
# 2649       0.004810          1
# 2650       0.004799          1
# 2651       0.004822          1
# 2652       0.004839          1
# 2653       0.004839          1
# 2654       0.004839          1
# 2655       0.004839          1
# 2656       0.004848          1
# 2657       0.004857          1
# 2658       0.004882          1
# 2659       0.004858          1
# 2660       0.004829          1
# 2661       0.004848          1
# 2662       0.004841          1
# 2663       0.004849          1
# 2664       0.004860          1
#
# [2665 rows x 7 columns]

# %%
#Посмотрим верхушку таблицы
data.head()
# Out:
#                   date  Temperature  Humidity       Light         CO2  \
# 0  2015-02-02 14:19:00      23.7000    26.272  585.200000  749.200000
# 1  2015-02-02 14:19:59      23.7180    26.290  578.400000  760.400000
# 2  2015-02-02 14:21:00      23.7300    26.230  572.666667  769.666667
# 3  2015-02-02 14:22:00      23.7225    26.125  493.750000  774.750000
# 4  2015-02-02 14:23:00      23.7540    26.200  488.600000  779.000000
#
#    HumidityRatio  Occupancy
# 0       0.004764          1
# 1       0.004773          1
# 2       0.004765          1
# 3       0.004744          1
# 4       0.004767          1

# %%
#Посмотрим конец таблицы
data.tail()
# Out:
#                      date  Temperature   Humidity  Light      CO2  \
# 2660  2015-02-04 10:38:59    24.290000  25.700000  808.0  1150.25
# 2661  2015-02-04 10:40:00    24.330000  25.736000  809.8  1129.20
# 2662  2015-02-04 10:40:59    24.330000  25.700000  817.0  1125.80
# 2663  2015-02-04 10:41:59    24.356667  25.700000  813.0  1123.00
# 2664  2015-02-04 10:43:00    24.408333  25.681667  798.0  1124.00
#
#       HumidityRatio  Occupancy
# 2660       0.004829          1
# 2661       0.004848          1
# 2662       0.004841          1
# 2663       0.004849          1
# 2664       0.004860          1

# %%
#Выведем размер таблицы (строк, столбцов)
print(data.shape)
# Out:
# (2665, 7)

# %%
#Посмотрим тип данных
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
type(data['date'])
# Out:
# pandas.core.series.Series

# %%
#Выведем названия столбцов
print(data.columns)
# Out:
# Index(['date', 'Temperature', 'Humidity', 'Light', 'CO2', 'HumidityRatio',
#        'Occupancy'],
#       dtype='object')

# %%
#Посмотрим общую характеристику текущего набора
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2665 entries, 0 to 2664
# Data columns (total 7 columns):
# date             2665 non-null object
# Temperature      2665 non-null float64
# Humidity         2665 non-null float64
# Light            2665 non-null float64
# CO2              2665 non-null float64
# HumidityRatio    2665 non-null float64
# Occupancy        2665 non-null int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 145.8+ KB

# %%
#Посмотрим информацию по количественным признакам
data.describe()
# Out:
#        Temperature     Humidity        Light          CO2  HumidityRatio  \
# count  2665.000000  2665.000000  2665.000000  2665.000000    2665.000000
# mean     21.433876    25.353937   193.227556   717.906470       0.004027
# std       1.028024     2.436842   250.210906   292.681718       0.000611
# min      20.200000    22.100000     0.000000   427.500000       0.003303
# 25%      20.650000    23.260000     0.000000   466.000000       0.003529
# 50%      20.890000    25.000000     0.000000   580.500000       0.003815
# 75%      22.356667    26.856667   442.500000   956.333333       0.004532
# max      24.408333    31.472500  1697.250000  1402.250000       0.005378
#
#          Occupancy
# count  2665.000000
# mean      0.364728
# std       0.481444
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
#Посмотрим информацию по всем признакам
data.describe(include = 'all')
# Out:
#                        date  Temperature     Humidity        Light  \
# count                  2665  2665.000000  2665.000000  2665.000000
# unique                 2665          NaN          NaN          NaN
# top     2015-02-03 10:50:00          NaN          NaN          NaN
# freq                      1          NaN          NaN          NaN
# mean                    NaN    21.433876    25.353937   193.227556
# std                     NaN     1.028024     2.436842   250.210906
# min                     NaN    20.200000    22.100000     0.000000
# 25%                     NaN    20.650000    23.260000     0.000000
# 50%                     NaN    20.890000    25.000000     0.000000
# 75%                     NaN    22.356667    26.856667   442.500000
# max                     NaN    24.408333    31.472500  1697.250000
#
#                 CO2  HumidityRatio    Occupancy
# count   2665.000000    2665.000000  2665.000000
# unique          NaN            NaN          NaN
# top             NaN            NaN          NaN
# freq            NaN            NaN          NaN
# mean     717.906470       0.004027     0.364728
# std      292.681718       0.000611     0.481444
# min      427.500000       0.003303     0.000000
# 25%      466.000000       0.003529     0.000000
# 50%      580.500000       0.003815     0.000000
# 75%      956.333333       0.004532     1.000000
# max     1402.250000       0.005378     1.000000

# %%
#Выведем матрицу корреляции
data.corr()
# Out:
#                Temperature  Humidity     Light       CO2  HumidityRatio  \
# Temperature       1.000000  0.716988  0.768428  0.870226       0.894548
# Humidity          0.716988  1.000000  0.561905  0.911611       0.951914
# Light             0.768428  0.561905  1.000000  0.769167       0.693286
# CO2               0.870226  0.911611  0.769167  1.000000       0.964440
# HumidityRatio     0.894548  0.951914  0.693286  0.964440       1.000000
# Occupancy         0.705784  0.610764  0.927949  0.768030       0.700330
#
#                Occupancy
# Temperature     0.705784
# Humidity        0.610764
# Light           0.927949
# CO2             0.768030
# HumidityRatio   0.700330
# Occupancy       1.000000

# %%
#Построим матрицу ковариации
from pandas.plotting import scatter_matrix
scatter_matrix(data, alpha = .01, figsize = (16, 16))
pass

# %%
#Отрисуем график для переменных Температура и СО2
plt.plot(data['Temperature'], data['CO2'], 'o', alpha = 0.5)
plt.xlabel('Temperature')
plt.ylabel('CO2')
plt.title('Temperature vs CO2')
pass

# %%
#Посмотрим на уникальные значения в столбце
data['Occupancy'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
#Построим диаграмму рассеяния для Температуры и СО2, когда люди находились в комнате и не находились.
plt.figure(figsize = (10, 6))

plt.scatter(data[data['Occupancy'] == 0]['Temperature'],
            data[data['Occupancy'] == 0]['CO2'],
            alpha = 0.3,
            label = '2',
            color = 'b')

plt.scatter(data[data['Occupancy'] == 1]['Temperature'],
            data[data['Occupancy'] == 1]['CO2'],
            alpha = 0.3,
            label = '1',
            color = 'r')

plt.xlabel('Temperature')
plt.xticks(range(1, 25))
plt.xlim(20, 24)
plt.ylabel('CO2')
plt.legend()
plt.grid()

# %% [markdown]
# ## Подготовка данных

# %%
#Узнаем категории данных столбцов
data['Occupancy'].dtype.name
# Out:
# 'int64'

# %%
data['date'].dtype.name
# Out:
# 'object'

# %%
data['Light'].dtype.name
# Out:
# 'float64'

# %%
#Разделим имеющиеся столбцы на категориальные и на числовые
categorical_columns = [c for c in data.columns if data[c].dtype.name == 'object']
numerical_columns   = [c for c in data.columns if data[c].dtype.name != 'object']
print(categorical_columns)
print(numerical_columns)
# Out:
# ['date']
# ['Temperature', 'Humidity', 'Light', 'CO2', 'HumidityRatio', 'Occupancy']

# %% [markdown]
# ## Обрабатка пропущенных значений

# %%
data[numerical_columns].count(axis = 0)
# Out:
# Temperature      2665
# Humidity         2665
# Light            2665
# CO2              2665
# HumidityRatio    2665
# Occupancy        2665
# dtype: int64

# %%
#Пропущенные значения отсутствуют. Посмотрим среднее по столбцам
data.median(axis = 0)
# Out:
# Temperature       20.890000
# Humidity          25.000000
# Light              0.000000
# CO2              580.500000
# HumidityRatio      0.003815
# Occupancy          0.000000
# dtype: float64

# %% [markdown]
# ## Векторизация

# %%
#Векторизуем категориальные признаки
categorical_columns = pd.get_dummies(data[categorical_columns])
print(categorical_columns.columns)
# Out:
# Index(['date_2015-02-02 14:19:00', 'date_2015-02-02 14:19:59',
#        'date_2015-02-02 14:21:00', 'date_2015-02-02 14:22:00',
#        'date_2015-02-02 14:23:00', 'date_2015-02-02 14:23:59',
#        'date_2015-02-02 14:25:00', 'date_2015-02-02 14:25:59',
#        'date_2015-02-02 14:26:59', 'date_2015-02-02 14:28:00',
#        ...
#        'date_2015-02-04 10:34:00', 'date_2015-02-04 10:34:59',
#        'date_2015-02-04 10:36:00', 'date_2015-02-04 10:37:00',
#        'date_2015-02-04 10:38:00', 'date_2015-02-04 10:38:59',
#        'date_2015-02-04 10:40:00', 'date_2015-02-04 10:40:59',
#        'date_2015-02-04 10:41:59', 'date_2015-02-04 10:43:00'],
#       dtype='object', length=2665)

# %% [markdown]
# ## Нормализация

# %%
data_numerical = data[numerical_columns]
data_numerical.describe()
# Out:
#        Temperature     Humidity        Light          CO2  HumidityRatio  \
# count  2665.000000  2665.000000  2665.000000  2665.000000    2665.000000
# mean     21.433876    25.353937   193.227556   717.906470       0.004027
# std       1.028024     2.436842   250.210906   292.681718       0.000611
# min      20.200000    22.100000     0.000000   427.500000       0.003303
# 25%      20.650000    23.260000     0.000000   466.000000       0.003529
# 50%      20.890000    25.000000     0.000000   580.500000       0.003815
# 75%      22.356667    26.856667   442.500000   956.333333       0.004532
# max      24.408333    31.472500  1697.250000  1402.250000       0.005378
#
#          Occupancy
# count  2665.000000
# mean      0.364728
# std       0.481444
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
#Перед нормализацией удалим столбец Занятость, т.к. мы будем его предсказывать
data_numerical = data[numerical_columns]
data_numerical = data_numerical.drop(('Occupancy'), axis = 1)
data_core = data['Occupancy']
data_numerical.describe()
# Out:
#        Temperature     Humidity        Light          CO2  HumidityRatio
# count  2665.000000  2665.000000  2665.000000  2665.000000    2665.000000
# mean     21.433876    25.353937   193.227556   717.906470       0.004027
# std       1.028024     2.436842   250.210906   292.681718       0.000611
# min      20.200000    22.100000     0.000000   427.500000       0.003303
# 25%      20.650000    23.260000     0.000000   466.000000       0.003529
# 50%      20.890000    25.000000     0.000000   580.500000       0.003815
# 75%      22.356667    26.856667   442.500000   956.333333       0.004532
# max      24.408333    31.472500  1697.250000  1402.250000       0.005378

# %%
#Нормализация значений
data_numerical = (data_numerical - data_numerical.mean(axis = 0))/data_numerical.std(axis = 0)
data_numerical.describe()
# Out:
#         Temperature      Humidity         Light           CO2  HumidityRatio
# count  2.665000e+03  2.665000e+03  2.665000e+03  2.665000e+03   2.665000e+03
# mean   3.319024e-13  1.344833e-14  8.348544e-17  1.243950e-16   6.466264e-14
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00   1.000000e+00
# min   -1.200241e+00 -1.335309e+00 -7.722587e-01 -9.922262e-01  -1.185274e+00
# 25%   -7.625076e-01 -8.592828e-01 -7.722587e-01 -8.606840e-01  -8.148558e-01
# 50%   -5.290501e-01 -1.452440e-01 -7.722587e-01 -4.694740e-01  -3.471171e-01
# 75%    8.976349e-01  6.166709e-01  9.962493e-01  8.146285e-01   8.263135e-01
# max    2.893373e+00  2.510857e+00  6.011019e+00  2.338183e+00   2.212265e+00

# %% [markdown]
# ## Соединяем в одну таблицу

# %%
#Объединим данные. Вообщем я решил не включать дату считывания показания, ибо она нафиг не нужна.
data = pd.concat((data_numerical, data_core), axis = 1)
print(data.shape)
# Out:
# (2665, 6)

# %%
data.describe()
# Out:
#         Temperature      Humidity         Light           CO2  HumidityRatio  \
# count  2.665000e+03  2.665000e+03  2.665000e+03  2.665000e+03   2.665000e+03
# mean   3.319024e-13  1.344833e-14  8.348544e-17  1.243950e-16   6.466264e-14
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00   1.000000e+00
# min   -1.200241e+00 -1.335309e+00 -7.722587e-01 -9.922262e-01  -1.185274e+00
# 25%   -7.625076e-01 -8.592828e-01 -7.722587e-01 -8.606840e-01  -8.148558e-01
# 50%   -5.290501e-01 -1.452440e-01 -7.722587e-01 -4.694740e-01  -3.471171e-01
# 75%    8.976349e-01  6.166709e-01  9.962493e-01  8.146285e-01   8.263135e-01
# max    2.893373e+00  2.510857e+00  6.011019e+00  2.338183e+00   2.212265e+00
#
#          Occupancy
# count  2665.000000
# mean      0.364728
# std       0.481444
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
data_numerical.count(axis = 0)
# Out:
# Temperature      2665
# Humidity         2665
# Light            2665
# CO2              2665
# HumidityRatio    2665
# dtype: int64

# %% [markdown]
# ## X и y

# %%
X = data.drop(('Occupancy'), axis = 1)
y = data['Occupancy']
feature_names = X.columns

# %%
type(feature_names)
# Out:
# pandas.core.indexes.base.Index

# %%
feature_names
# Out:
# Index(['Temperature', 'Humidity', 'Light', 'CO2', 'HumidityRatio'], dtype='object')

# %%
print(X.shape)
print(y.shape)
N, d = X.shape
# Out:
# (2665, 5)
# (2665,)

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
#Получаем обучающие и тестовые выборки
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

N_train, _ = X_train.shape 
N_test,  _ = X_test.shape 

print(N_train, N_test)
# Out:
# 1865 800

# %% [markdown]
# ## kNN

# %%
#Объявляем классификатор с параметром k = 15. Проводим обучение модели на обучающей выборке X_train, y_train:
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 15)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=15, p=2,
#            weights='uniform')

# %%
knn
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=15, p=2,
#            weights='uniform')

# %%
#Применяем метод predict. Считаем среднюю ошибку
y_train_predict = knn.predict(X_train)
y_test_predict = knn.predict(X_test)

err_train = np.mean(y_train != y_train_predict)
err_test  = np.mean(y_test  != y_test_predict)

print(err_train, err_test)
# Out:
# 0.0193029490617 0.02

# %%
#Можно посчитать ошибку как 1 - точность, вычисленную через метод score в knn
err_test = 1 - knn.score(X_test, y_test)

# %%
err_test
# Out:
# 0.020000000000000018

# %%
#С помощью метода confusion matrix можно вычислить точность работы классификатора. Элемент матрицы (i, j) равен числу объектов из группы i, а предсказанных в группу j
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_test, y_test_predict))
# Out:
# [[512  12]
#  [  4 272]]

# %% [markdown]
# ## Подбор параметров

# %%
from sklearn.model_selection import GridSearchCV
nnb = [1, 3, 5, 10, 15, 20, 25, 35, 45, 55]
knn = KNeighborsClassifier()
grid = GridSearchCV(knn, param_grid = {'n_neighbors': nnb}, cv=10)
grid.fit(X_train, y_train)

best_cv_err = 1 - grid.best_score_
best_n_neighbors = grid.best_estimator_.n_neighbors
print(best_cv_err, best_n_neighbors)
# Out:
# 0.0123324396783 1

# %%
#Применим алгоритм еще раз с новым параметром k
knn = KNeighborsClassifier(n_neighbors=best_n_neighbors).fit(X_train, y_train)

err_train = np.mean(y_train != knn.predict(X_train))
err_test  = np.mean(y_test  != knn.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.01

# %% [markdown]
# ## Нейронные сети

# %% [markdown]
# ### Разбиваем данные на обучающую и тестовую выборки

# %%
#На исходном наборе данных с помощью нейронных сетей решается задача классификации, 
#а именно определение занятости комнаты.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 7)
N_test, _ = X_test.shape

# %% [markdown]
# ### Обучаем классификатор

# %%
#Обучение классификатора вида многослойного персептрона. Активационная функция: сигмоида. Один скрытый слой, с количеством
#нейронов: 100
from sklearn.neural_network import MLPClassifier
mlp_model = MLPClassifier(hidden_layer_sizes = (100,), solver = 'lbfgs', activation = 'logistic', random_state = 54)
mlp_model.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='logistic', alpha=0.0001, batch_size='auto',
#        beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=54, shuffle=True,
#        solver='lbfgs', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %%
y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)

print(np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred))
#Наблюдается переобучение, т.к. ошибка на тестовой выборке выше, чем на обучающей.
# Out:
# 0.00672268907563 0.0215909090909

# %%
mlp_model = MLPClassifier(hidden_layer_sizes = (20,20), solver = 'lbfgs', activation = 'logistic', random_state = 54)
mlp_model.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='logistic', alpha=0.0001, batch_size='auto',
#        beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(20, 20), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=54, shuffle=True,
#        solver='lbfgs', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %%
y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)

print(np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred))
#Наблюдаем переобучение, увеличим количество нейронов
# Out:
# 0.0145658263305 0.0215909090909

# %%
mlp_model = MLPClassifier(hidden_layer_sizes = (50,40), solver = 'lbfgs', activation = 'logistic', random_state = 54)
mlp_model.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='logistic', alpha=0.0001, batch_size='auto',
#        beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(50, 40), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=54, shuffle=True,
#        solver='lbfgs', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %%
y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)

print(np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred))
#Минимальные значения ошибок, которые я смог получить, соответственно оптимальные значения нейронов на двух скрытых слоях
# должны быть (>30, <50)
# Out:
# 0.0078431372549 0.0204545454545

# %% [markdown]
# ## Подбор гиперпараметров

# %%
#Построим график зависимости ошибок от количества нейронов в скрытом слое (1 скрытый слой)
nodes_arr_1 = np.arange(30, 50, 1)
test_err = []
train_err = []
for nodes in nodes_arr_1:
    mlp_model = MLPClassifier(hidden_layer_sizes = (nodes,), solver = 'lbfgs',
                              activation = 'logistic', random_state = 54)
    mlp_model.fit(X_train, y_train)

    y_train_pred = mlp_model.predict(X_train)
    y_test_pred = mlp_model.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))

print("Минимальное значение ошибки:")
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)

print("Оптимальное значение количества нейронов:")
nodes_opt_1 = nodes_arr_1[test_err == min_test_err][0]
print(nodes_opt_1)

plt.semilogx(nodes_arr_1, train_err, 'b-o', label = 'train')
plt.semilogx(nodes_arr_1, test_err, 'r-o', label = 'test')
plt.xlim([np.max(nodes_arr_1), np.min(nodes_arr_1)])
plt.title('Error vs. nodes count')
plt.xlabel('nodes')
plt.ylabel('error')
plt.legend()
pass
# Out:
# Минимальное значение ошибки:
# 0.00392156862745 0.0147727272727
# Оптимальное значение количества нейронов:
# 47

# %%
#Построим график зависимости ошибок от количества нейронов в скрытых слоях (2 скрытых слоя с одинаковым количеством нейронов)
nodes_arr_2 = np.arange(30, 50, 1)
test_err = []
train_err = []
for nodes in nodes_arr_2:
    mlp_model = MLPClassifier(hidden_layer_sizes = (nodes, nodes), solver = 'lbfgs',
                              activation = 'logistic', random_state = 54)
    mlp_model.fit(X_train, y_train)

    y_train_pred = mlp_model.predict(X_train)
    y_test_pred = mlp_model.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))

print("Минимальное значение ошибки:")
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)

print("Оптимальное значение количества нейронов:")
nodes_opt_2 = nodes_arr_2[test_err == min_test_err][0]
print(nodes_opt_2)

plt.semilogx(nodes_arr_2, train_err, 'b-o', label = 'train')
plt.semilogx(nodes_arr_2, test_err, 'r-o', label = 'test')
plt.xlim([np.max(nodes_arr_2), np.min(nodes_arr_2)])
plt.title('Error vs. nodes count')
plt.xlabel('nodes')
plt.ylabel('error')
plt.legend()
pass
#Везде наблюдается переобучение
# Out:
# Минимальное значение ошибки:
# 0.00224089635854 0.0125
# Оптимальное значение количества нейронов:
# 39

# %% [markdown]
# ### Подбор параметра регуляризации alpha

# %%
#С двумя скрытыми слоями ошибка на обоих выборках ниже, поэтому будем использовать два скрытых слоя
alpha_arr = np.logspace(-5, 5, 50)
test_err = []
train_err = []
for alpha in alpha_arr:
    mlp_model = MLPClassifier(alpha = alpha, hidden_layer_sizes = (nodes_opt_2, nodes_opt_2), 
                              solver = 'lbfgs', activation = 'logistic', random_state = 54)
    mlp_model.fit(X_train, y_train)

    y_train_pred = mlp_model.predict(X_train)
    y_test_pred = mlp_model.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))

print("Минимальное значение ошибки:")
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)

print("Оптимальное значение alpha:")
alpha_opt = alpha_arr[test_err == min_test_err][0]
print(alpha_opt)

plt.semilogx(alpha_arr, train_err, 'b-o', label = 'train')
plt.semilogx(alpha_arr, test_err, 'r-o', label = 'test')
plt.xlim([np.max(alpha_arr), np.min(alpha_arr)])
plt.title('Error vs. alpha')
plt.xlabel('alpha')
plt.ylabel('error')
plt.legend()
pass
# Out:
# Минимальное значение ошибки:
# 0.00896358543417 0.0125
# Оптимальное значение alpha:
# 0.000104811313415

# %% [markdown]
# ### Классификатор на найденных оптимальных значениях

# %%
#Да и вообще - данные сильно коррелированы.
mlp_model = MLPClassifier(alpha = alpha_opt, hidden_layer_sizes = (nodes_opt_2, nodes_opt_2),
                          solver = 'lbfgs', activation = 'logistic', random_state = 42)
mlp_model.fit(X_train, y_train)

y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)

print("Ошибки на обучающей и тестовой выборках:")
print(np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred))
# Out:
# Ошибки на обучающей и тестовой выборках:
# 0.0112044817927 0.0147727272727

# %% [markdown]
# ## Random forest

# %%
#На исходном наборе данных с помощью нейронных сетей решается задача классификации, 
#а именно определение занятости комнаты с помощью Random forest.
#Разобьем данные на обучающую и тестовую выборки

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

# %%
#Обучаем классификатор вида Random Forest. Число деревьев = 100
from sklearn import ensemble
rf = ensemble.RandomForestClassifier(n_estimators = 100)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
#Считаем среднюю ошибку

err_train = np.mean(y_train != rf.predict(X_train))
err_test  = np.mean(y_test  != rf.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.0147727272727

# %%
#Наблюдаем переобучение: ошибка на тестовой выборке выше, чем на обучающей.
#Построим график зависимости ошибки на обучающей и тестовой выборках,
#а также out-of-bag ошибки (oob-ошибки) от количества деревьев.

trees_arr = np.arange(25, 126, 5)
test_err = []
train_err = []
oob_err = []
for trees in trees_arr:
    rf = ensemble.RandomForestClassifier(n_estimators = trees, oob_score=True)
    rf.fit(X_train, y_train)
    train_err.append(np.mean(y_train != rf.predict(X_train)))
    test_err.append(np.mean(y_test  != rf.predict(X_test)))
    oob_err.append(1 - rf.oob_score_)

plt.plot(trees_arr, train_err, 'b-o', label = 'train')
plt.plot(trees_arr, test_err, 'r-o', label = 'test')
plt.plot(trees_arr, oob_err, 'g-o', label = 'oob')
plt.xlim([np.max(trees_arr), np.min(trees_arr)])
plt.title('Error vs. number of trees')
plt.xlabel('trees')
plt.ylabel('error')
plt.legend()
pass

# %%
#Переобучение наблюдается на всем экспериментальном множестве количества деревьев.
#Минимальное значение ошибки

min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# 0.0 0.0147727272727

# %%
#Оптимальное количество деревьев

trees_opt = trees_arr[test_err == min_test_err]
trees_opt = trees_opt[0]
print(trees_opt)
# Out:
# 30

# %% [markdown]
# ## Extremely Randomized Trees

# %%
#На исходном наборе данных с помощью нейронных сетей решается задача классификации, 
#а именно определение занятости комнаты с помощью Extremely Randomized Trees.
#Разобьем данные на обучающую и тестовую выборки

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

# %%
#Обучаем классификатор вида Extremely Randomized Trees. Число деревьев = 100

ert = ensemble.ExtraTreesClassifier(n_estimators = 100)
ert.fit(X_train, y_train)
# Out:
# ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#            max_depth=None, max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
#Считаем среднюю ошибку

err_train = np.mean(y_train != ert.predict(X_train))
err_test  = np.mean(y_test  != ert.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.0136363636364

# %%
#Наблюдаем переобучение: ошибка на тестовой выборке выше, чем на обучающей.
#Построим график зависимости ошибки на обучающей и тестовой выборках,
#а также out-of-bag ошибки (oob-ошибки) от количества деревьев.

trees_arr = np.arange(25, 126, 5)
test_err = []
train_err = []
oob_err = []
for trees in trees_arr:
    ert = ensemble.ExtraTreesClassifier(n_estimators = trees, oob_score=True, bootstrap=True)
    ert.fit(X_train, y_train)
    train_err.append(np.mean(y_train != ert.predict(X_train)))
    test_err.append(np.mean(y_test  != ert.predict(X_test)))
    oob_err.append(1 - ert.oob_score_)

plt.plot(trees_arr, train_err, 'b-o', label = 'train')
plt.plot(trees_arr, test_err, 'r-o', label = 'test')
plt.plot(trees_arr, oob_err, 'g-o', label = 'oob')
plt.xlim([np.max(trees_arr), np.min(trees_arr)])
plt.title('Error vs. number of trees')
plt.xlabel('trees')
plt.ylabel('error')
plt.legend()
pass

# %%
#Переобучение наблюдается на всем экспериментальном множестве количества деревьев.
#Минимальное значение ошибки

min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# 0.0 0.0125

# %%
#Оптимальное количество деревьев

trees_opt = trees_arr[test_err == min_test_err]
trees_opt = trees_opt[0]
print(trees_opt)
# Out:
# 75

# %% [markdown]
# ## AdaBoost

# %%
#На исходном наборе данных с помощью нейронных сетей решается задача классификации, 
#а именно определение занятости комнаты с помощью AdaBoost.
#Разобьем данные на обучающую и тестовую выборки

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

# %%
#Обучаем классификатор вида AdaBoost. Количество классификаторов = 100

ab = ensemble.AdaBoostClassifier(n_estimators = 100)
ab.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#           learning_rate=1.0, n_estimators=100, random_state=None)

# %%
#Считаем среднюю ошибку

err_train = np.mean(y_train != ab.predict(X_train))
err_test  = np.mean(y_test  != ab.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.0159090909091

# %%
#Наблюдаем переобучение: ошибка на тестовой выборке выше, чем на обучающей.
#Построим график зависимости ошибки на обучающей и тестовой выборках.

estim_arr = np.arange(25, 126, 5)
test_err = []
train_err = []
for estim in estim_arr:
    ab = ensemble.AdaBoostClassifier(n_estimators = estim)
    ab.fit(X_train, y_train)
    train_err.append(np.mean(y_train != ab.predict(X_train)))
    test_err.append(np.mean(y_test  != ab.predict(X_test)))

plt.plot(estim_arr, train_err, 'b-o', label = 'train')
plt.plot(estim_arr, test_err, 'r-o', label = 'test')
plt.xlim([np.max(estim_arr), np.min(estim_arr)])
plt.title('Error vs. number of estimators')
plt.xlabel('estimators')
plt.ylabel('error')
plt.legend()
pass

# %%
#Наблюдаем переобучение
#Минимальное значение ошибки

min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# 0.0 0.0159090909091

# %%
#Оптимальное количество классификаторов

estim_opt = estim_arr[test_err == min_test_err]
estim_opt = estim_opt[0]
print(estim_opt)
# Out:
# 35

# %% [markdown]
# ## Gradient Boosted Trees

# %%
#На исходном наборе данных с помощью нейронных сетей решается задача классификации, 
#а именно определение занятости комнаты с помощью Gradient Boosted Trees.
#Разобьем данные на обучающую и тестовую выборки

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

# %%
#Обучаем классификатор вида Gradient Boosted Trees. Число деревьев = 100

gbt = ensemble.GradientBoostingClassifier(n_estimators = 100)
gbt.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=None, subsample=1.0, verbose=0,
#               warm_start=False)

# %%
#Считаем среднюю ошибку

err_train = np.mean(y_train != gbt.predict(X_train))
err_test  = np.mean(y_test  != gbt.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.0170454545455

# %%
#Наблюдаем переобучение: ошибка на тестовой выборке выше, чем на обучающей.
#Построим график зависимости ошибки на обучающей и тестовой выборках.

trees_arr = np.arange(25, 126, 5)
test_err = []
train_err = []
for trees in trees_arr:
    gbt = ensemble.GradientBoostingClassifier(n_estimators = trees)
    gbt.fit(X_train, y_train)
    train_err.append(np.mean(y_train != gbt.predict(X_train)))
    test_err.append(np.mean(y_test  != gbt.predict(X_test)))

plt.plot(trees_arr, train_err, 'b-o', label = 'train')
plt.plot(trees_arr, test_err, 'r-o', label = 'test')
plt.xlim([np.max(trees_arr), np.min(trees_arr)])
plt.title('Error vs. number of trees')
plt.xlabel('trees')
plt.ylabel('error')
plt.legend()
pass

# %%
#Наблюдаем переобучение
#Минимальное значение ошибки

min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# 0.0 0.0125

# %%
#Оптимальное количество деревьев

trees_opt = trees_arr[test_err == min_test_err]
trees_opt = trees_opt[0]
print(trees_opt)
# Out:
# 30

# %% [markdown]
# ## Principal component analysis (PCA)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 5)
X_pca = pca.fit_transform(X)
X_pca.shape
# Out:
# (2665, 5)

# %%
#Разделим данные на тестовую и обучающие выборки
X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size = 0.33, random_state = 42)

# %%
#Обучаем классификатор вида Extremely Randomized Trees. Число деревьев = 100
ert = ensemble.ExtraTreesClassifier(n_estimators = 100)
ert.fit(X_train, y_train)
# Out:
# ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#            max_depth=None, max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
#Считаем среднюю ошибку
err_train = np.mean(y_train != ert.predict(X_train))
err_test  = np.mean(y_test  != ert.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.0102272727273

# %%
#Наблюдаем переобучение
#Построим график зависимости ошибки на тестовой и обучающей выборках от количества компонент в методе.
components_arr = np.arange(1, 5, 1)
test_err = []
train_err = []
oob_err = []
for components in components_arr:
    pca = PCA(n_components = components)
    X_pca = pca.fit_transform(X)
    X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size = 0.33, random_state = 42)

    ert = ensemble.ExtraTreesClassifier(n_estimators = 100, bootstrap = True, oob_score = True)
    ert.fit(X_train, y_train)
    
    train_err.append(np.mean(y_train != ert.predict(X_train)))
    test_err.append(np.mean(y_test  != ert.predict(X_test)))
    oob_err.append(1 - ert.oob_score_)

plt.figure(figsize = (10, 6))
plt.plot(components_arr, train_err, 'b-o', label = 'train')
plt.plot(components_arr, test_err, 'r-o', label = 'test')
plt.plot(components_arr, oob_err, 'g-o', label = 'oob')
plt.xlim([np.min(components_arr), np.max(components_arr)])
plt.title('Error vs. number of components')
plt.xlabel('components')
plt.ylabel('error')
plt.legend()
pass

# %%
#Наблюдаем переобучение
print("Минимальная ошибка:")
print(np.min(train_err), np.min(test_err))
print("Оптимальное количество компонент:")
print(components_arr[test_err == np.min(test_err)][0])
# Out:
# Минимальная ошибка:
# 0.0 0.0136363636364
# Оптимальное количество компонент:
# 4
